# %% [markdown]
# <p style="font-size:20px;">Simulator: QiskitAer, FakeTorino, ideal device noise simulator (no shot noise). H2 in minimal basis (STO-3G), JW mapping, 1-layered tUPS. With 40 samples generated randomly, number of parameters is 3, number of non Clifford parameters k = 1. Fitting methods: Square regression with a linear ansatz, Nonlinear Fitting, XGB, MLP.</p>

# %%
import pyscf
import slowquant.SlowQuant as sq
from qiskit_nature.second_q.mappers import JordanWignerMapper
from slowquant.qiskit_interface.interface import QuantumInterface
from slowquant.qiskit_interface.wavefunction import WaveFunction
#from slowquant.qiskit_interface.linear_response.projected import quantumLR

from qiskit_ibm_runtime.fake_provider import FakeTorino

from qiskit.primitives import Estimator

from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel
from qiskit_aer.primitives import Sampler
from qiskit_aer.primitives import SamplerV2

from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

import numpy as np
from scipy.optimize import minimize
from scipy.optimize import curve_fit
import random

from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor

import matplotlib.pyplot as plt

# %%
mol = pyscf.M(atom="""H 0.0 0.0 0.0;
                      H 0.735 0.0 0.0;""", basis="sto-3g", unit="angstrom")
rhf = pyscf.scf.RHF(mol).run()

sampler = Estimator()
primitive = sampler
mapper = JordanWignerMapper()
QI = QuantumInterface(primitive, "tUPS", mapper, ansatz_options={"n_layers": 1}, ISA = True)

#Remember to change the wavefunction to the correct molecule

WF = WaveFunction(
    mol.nao * 2,
    mol.nelectron,
    (2, 2),
    rhf.mo_coeff,
    mol.intor("int1e_kin") + mol.intor("int1e_nuc"),
    mol.intor("int2e"),
    QI,
)

WF.run_vqe_2step("RotoSolve")

#no noise
nonclif_ground_state_energy = WF.energy_elec
print("Non-Clifford Ground state energy:", nonclif_ground_state_energy)

#device noise
# Update the primitive with simulated noise
backend = FakeTorino()
QI.pass_manager = generate_preset_pass_manager(3,backend=backend,seed_transpiler=123) # seeded standard transpiler
QI.do_postselection = False
QI.do_M_mitigation = False
noise_model = NoiseModel.from_backend(backend)
sampler = Sampler(backend_options={"noise_model":noise_model})
WF.change_primitive(sampler)    
# Calculate the ground state energy using the noisy simulator
noisy_nonclif_ground_state_energy = WF.energy_elec
print("Noisy Non-Clifford Ground state energy:",noisy_nonclif_ground_state_energy)
# Out:
# converged SCF energy = -1.116998996754
# Number of shots is None. Ideal simulator is assumed.
# /tmp/ipykernel_2183732/317835389.py:5: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   sampler = Estimator()
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# Full optimization
# Iteration # | Iteration time [s] | Electronic energy [Hartree]
# --------Ansatz optimization
# --------Iteration # | Iteration time [s] | Electronic energy [Hartree]
# --------     1      |         3.40       |     -1.8572750302023797
# Non-Clifford Ground state energy: -1.8572750302023793
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Noisy Non-Clifford Ground state energy: -1.732580263299815

# %%
#prepare training set
clif_ground_state_energies = []
noisy_clif_ground_state_energies = []
results_linear = []
results_nonlinear = []
results_xgb = []
results_mlp = []
i = 3
for k in range(i):
    n_replacements = k + 1
    for n in range(30):
        QI = QuantumInterface(primitive, "tUPS", mapper, ansatz_options={"n_layers": 1}, ISA = True)

        WF = WaveFunction(
        mol.nao * 2,
        mol.nelectron,
        (2, 2),
        rhf.mo_coeff,
        mol.intor("int1e_kin") + mol.intor("int1e_nuc"),
        mol.intor("int2e"),
        QI,
        )
        indices_to_replace = random.sample(range(len(WF.ansatz_parameters)), n_replacements)
        for index in indices_to_replace:
            WF.ansatz_parameters[index] = random.uniform(0, 2*np.pi)
        print(WF.ansatz_parameters)
        clif_ground_state_energy = WF.energy_elec
        clif_ground_state_energies.append(clif_ground_state_energy)
        
        backend = FakeTorino()
        QI.pass_manager = generate_preset_pass_manager(3,backend=backend,seed_transpiler=123) # seeded standard transpiler
        QI.do_postselection = False
        QI.do_M_mitigation = False
        noise_model = NoiseModel.from_backend(backend)
        sampler = Sampler(backend_options={"noise_model":noise_model})
        WF.change_primitive(sampler)   
        noisy_clif_ground_state_energy = WF.energy_elec
        noisy_clif_ground_state_energies.append(noisy_clif_ground_state_energy)

    #data preparation
    nonclif_ground_state_energies = [nonclif_ground_state_energy for _ in range(len(clif_ground_state_energies))]
    noisy_nonclif_ground_state_energies = [noisy_nonclif_ground_state_energy for _ in range(len(noisy_clif_ground_state_energies))]
    X = np.array(noisy_clif_ground_state_energies).reshape(-1, 1)
    y = np.array(clif_ground_state_energies)
    X_test = np.array(noisy_nonclif_ground_state_energies).reshape(-1, 1)
    y_test = np.array(nonclif_ground_state_energies)

    #square regression with a linear ansatz
    def cost_function(a, X_exact, X_noisy):
        a1, a2 = a  # 将参数 a 拆分为 a1 和 a2
        # 计算代价函数 C 的值
        C = np.sum((X_exact - (a1 * X_noisy + a2))**2)
        return C
    X_exact = np.array(clif_ground_state_energies)
    X_noisy = np.array(noisy_clif_ground_state_energies)
    # 初始猜测值 a1 和 a2
    initial_guess = [1, 0]
    # 最小化代价函数
    result = minimize(cost_function, initial_guess, args=(X_exact, X_noisy))
    # 得到最优的 a1 和 a2
    a1_optimal, a2_optimal = result.x
    #print(f"最优的 a1 值: {a1_optimal}")
    #print(f"最优的 a2 值: {a2_optimal}")
    y_pred_linear = a1_optimal*noisy_nonclif_ground_state_energy + a2_optimal
    print('result of square regression:', y_pred_linear)
    results_linear.append(y_pred_linear)

    #Nonlinear Fitting
    # 定义非线性拟合函数
    def nonlinear_model(X_noisy, a1, a2, a3):
        return a1 * X_noisy**2 + a2 * X_noisy + a3
    # 输入数据
    X_exact = np.array(clif_ground_state_energies)
    X_noisy = np.array(noisy_clif_ground_state_energies)
    # 使用 curve_fit 进行非线性拟合
    # 初始猜测值 [a1, a2, a3]
    initial_guess = [1, 1, 0]
    params, covariance = curve_fit(nonlinear_model, X_noisy, X_exact, p0=initial_guess)
    # 提取拟合参数
    a1_optimal, a2_optimal, a3_optimal = params
    #print(f"最优的 a1 值: {a1_optimal}")
    #print(f"最优的 a2 值: {a2_optimal}")
    #print(f"最优的 a3 值: {a3_optimal}")
    #对新的数据进行预测
    y_pred_nonlinear = nonlinear_model(noisy_nonclif_ground_state_energy, a1_optimal, a2_optimal, a3_optimal)
    print('Result of Nonlinear Fitting:', y_pred_nonlinear)
    results_nonlinear.append(y_pred_nonlinear)

    #XGBoost
    xgb_model = XGBRegressor(max_depth=20, eta=0.0005, subsample=0.7, colsample_bytree=0.7, objective='reg:absoluteerror', n_estimators=1000, random_state=42)
    xgb_model.fit(X, y)
    y_pred_xgb = xgb_model.predict(X_test)
    # 计算均方误差
    #mse_corrected_XGB = mean_squared_error(y_test, y_pred_xgb)
    #print('mse:', mse_corrected_XGB)
    print('result of xgb:', y_pred_xgb[0])
    results_xgb.append(y_pred_xgb[0])

    #MLP
    # 归一化数据
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    # 训练MLP模型
    mlp_model = MLPRegressor(hidden_layer_sizes=(120, 60), activation='relu', solver='adam', max_iter=2000, alpha=0.001, random_state=42)
    mlp_model.fit(X_scaled, y)
    X_test_scaled = scaler.transform(X_test)
    y_pred_mlp = mlp_model.predict(X_test_scaled)
    #mse_corrected_MLP = mean_squared_error(y_test, y_pred_mlp)
    #print('mse:', mse_corrected_MLP)
    print('result of mlp:', y_pred_mlp[0])
    results_mlp.append(y_pred_mlp[0])
# Out:
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 3.9958327622115077]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 3.3900876753450278, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 1.221625087807074, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 4.162796209899061, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 0.9160247284176628]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 5.900307458858907]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.958051865600691, 0.0, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 4.779450496844899]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 1.7136092645576946]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.631549202526935, 0.0, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 2.6442306595313037, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 3.6835583217531584, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 0.2580200879343062]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 1.660136640979724, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 2.8134439602104466]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 2.184381390396963]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 3.890785708078336, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [3.1828484002065234, 0.0, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 1.3677683153874378]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 3.358246476499315, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [4.355692193283757, 0.0, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 1.486489657257529]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 6.1830623851903175, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 5.829279952290973]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.4692990000909576, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 4.533704706338088]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [3.445881206741196, 0.0, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 5.075605261875969, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 2.2430444256788924]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.0, 2.9088539488962692]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# result of square regression: -1.845563685206217
# Result of Nonlinear Fitting: -1.8521883775658208
# result of xgb: -1.2513047
# result of mlp: -1.9266713564785376
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 4.926587906259029, 1.0452945166550458]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 3.460060592058298, 0.8884846576817504]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [3.0864001190619366, 0.0, 5.9663063222594594]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 6.208110243325289, 3.503303100648092]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [1.4249172086004696, 0.5782049369645706, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [3.291646309987628, 0.0, 1.8659304166072237]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [3.5555180352324047, 0.0, 2.3096716761042]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 0.49754227333195034, 0.5357724610236589]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 1.184716518229274, 4.930742748209064]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [4.188062760377468, 1.8717245585241333, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.551390627025789, 0.0, 4.302335950429793]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.6489788511587475, 3.6760213593036455, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.33838600722311, 0.0, 5.560708035230651]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.492777303369442, 1.4554524159751365, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.8007268105084989, 5.667810468449253, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.0, 5.918272717298541, 5.601161145817142]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [6.133198071022303, 6.242251887765766, 0.0]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.1967033697845613, 0.0, 0.41954646001373286]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.6485462846559973, 0.0, 5.066270563197863]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# ...
# [0.4560962593338175, 5.183102718189449, 3.2219462927266105]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [2.15472602306625, 0.6483070678151691, 3.914328276382229]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.27897935189605, 5.548690117256442, 5.186224969016943]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [1.8737200400011054, 1.8760679673744294, 0.5939684535345765]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [4.7764569900639255, 1.6785827494621262, 1.8802103148125993]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.183635943642674, 4.783146608771156, 0.37127338281696737]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.5893540222513485, 0.09817005435508909, 0.46588507346160624]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [1.5222577650848963, 2.4646735532394173, 2.9465149676004625]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [3.148198842286889, 5.105689256478966, 5.73558279799044]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [5.33070895434508, 5.317058266707353, 3.079167543612235]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [4.502612602221885, 6.073402533883232, 4.218590598612718]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [3.589153181387283, 0.16980466241825568, 3.5376139969296325]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.3093824448811, 2.5404682703007224, 4.992212778641343]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [2.846099265364644, 4.297055348609101, 1.0553265474082698]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [0.5818468684485224, 4.914317604824625, 4.3514352091856985]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# Number of shots is None. Ideal simulator is assumed.
# You selected ISA but did not pass a PassManager. Standard internal transpilation will use backend None with optimization level 3
# [4.408559164157016, 0.8834434470267895, 1.5844964458083406]
# Using this function is only recommended for switching from ideal simulator to shot-noise or quantum hardware.
#                  Multiple switching back and forth can lead to un-expected outcomes and is an experimental feature.
#
# Reset RDMs, energies, and QI metrics.
# Number of shots is None. Ideal simulator is assumed.
# Your settings are:
#  Ansatz:              tUPS
#  Number of shots:     None
#  ISA                  True
#  Transpiled circuit   True
#  Primitive:           Sampler
#  Post-processing:     False
#  Circuit layout:      [103, 93, 102, 104]
#  Non-local gates:     36
#  Transpilation strategy: External PassManager
#  Primitive backend:   AerSimulator('aer_simulator'
#              noise_model=<NoiseModel on ['measure', 'reset', 'cz', 'x', 'sx', 'id']>)
#
# result of square regression: -1.8539694907283601
# Result of Nonlinear Fitting: -1.8546148097965536
# result of xgb: -1.1291295
# result of mlp: -1.987929999203488

# %%
exact = [nonclif_ground_state_energy for _ in range(i)]
# 绘制折线图
plt.plot(results_linear, marker='None', linestyle='-', color='b', label='linear')
plt.plot(results_nonlinear, marker='None', linestyle='-', color='y', label='nonlinear')
plt.plot(results_xgb, marker='None', linestyle='-', color='r', label='xgb')
plt.plot(results_mlp, marker='None', linestyle='-', color='g', label='mlp')
plt.plot(exact, marker='None', linestyle='-', color='k', label='exact')
# 限制 y 轴范围
#plt.ylim(-3.8, -3)
# 添加标题和标签
plt.title("impact of N")
plt.xlabel("# of samples")
plt.ylabel("Predict Results [Ha]")

# 添加网格
#plt.grid(True, linestyle='--', alpha=0.6)

# 显示图例
plt.legend()

# 显示图像
plt.show()

# %%
# 绘制折线图
plt.plot(results_linear, marker='None', linestyle='-', color='b', label='linear')
plt.plot(results_nonlinear, marker='None', linestyle='-', color='y', label='nonlinear')
plt.plot(results_xgb, marker='None', linestyle='-', color='r', label='xgb')
plt.plot(results_mlp, marker='None', linestyle='-', color='g', label='mlp')
plt.plot(exact, marker='None', linestyle='-', color='k', label='exact')
# 限制 y 轴范围
plt.ylim(-1.9, -1.8)
# 添加标题和标签
plt.title("impact of N")
plt.xlabel("# of samples")
plt.ylabel("Predict Results [Ha]")

# 添加网格
#plt.grid(True, linestyle='--', alpha=0.6)

# 显示图例
plt.legend()

# 显示图像
plt.show()

# %%
# 数据
categories = ['Exact', 'Linear', 'Nonlinear', 'XGB', 'MLP']
values = [nonclif_ground_state_energy, y_pred_linear, y_pred_nonlinear, y_pred_xgb[0], y_pred_mlp[0]]

# 绘制柱状图
plt.bar(categories, values, color='skyblue')

# 添加标题和标签
plt.title('CDR_randomly_H2')
plt.xlabel('Regression Methods')
plt.ylabel('Predict Results [Ha]')

# 在每个柱子上标注数值
for i, v in enumerate(values):
    plt.text(i, v + 0.5, str(v), ha='center', fontsize=6)

# 显示图表
plt.show()
